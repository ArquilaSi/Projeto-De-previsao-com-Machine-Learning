# %% [markdown]
# # Projeto Python IA: Inteligência Artificial e Previsões
#
# ### Case: Score de Crédito dos Clientes
#
# Você foi contratado por um banco para conseguir definir o score de crédito dos clientes. Você precisa analisar todos os clientes do banco e, com base nessa análise, criar um modelo que consiga ler as informações do cliente e dizer automaticamente o score de crédito dele: Ruim, Ok, Bom
#
# Arquivos da aula: https://drive.google.com/drive/folders/1FbDqVq4XLvU85VBlVIMJ73p9oOu6u2-J?usp=drive_link

# %%
#Analisando 1 cliente
#Se o cliente é Bom ou Ruim(Nota de Crédito dele = Score de Crédito)

#Passo a Passo do Projeto
#Passo 0: Entender o desafio da empresa (Prever a nota de crédito do cliente com precisão)
#Passo 1: Importar a base de dados (Com as informações dos clientes)
#Passo 2: Tratar e Preparar a base de dados para a Inteligencia Artificial(A mesma precisa que a base de dados esteja estruturada de forma correta/Precisa ter um padrão)
#Passo 3: Modelo de previsão ou Modelo de IA -> A mesma vai informar se a nota de crédito do cliente é Ruim, Ok ou Boa
#Passo 4: Avaliar e Escolher o melhor modelo(Vou criar várias maneiras e comparalas para ver qual é a melhor ou atende ao meu objetivo)
#Passo 5: Fazer novas previsões

# %%
#Analisando 1 cliente
#Se o cliente é Bom ou Ruim(Nota de Crédito dele = Score de Crédito)

#Passo a Passo do Projeto
#Passo 0: Entender o desafio da empresa (Prever a nota de crédito do cliente com precisão)
#Passo 1: Importar a base de dados (Com as informações dos clientes)
#Preciso instalar as bibliotecas pandas scikit-learn (pip install pandas scikit-learn)

import pandas
